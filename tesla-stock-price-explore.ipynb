# %% [markdown]
# ![th.jpg](attachment:7fd3960b-8f2a-4bf2-b2b8-331603bf127a.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('../input/tesla-stock-price/Tesla.csv - Tesla.csv.csv')

# %%
data_set
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# ...

# %%
data_set.shape
# Out:
# (1692, 7)

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
data_set.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
print("Columns are in Data_set", data_set.columns)
# Out:
# Columns are in Data_set Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
print("Average Open Share Price :- ", np.median(data_set['Open']))
# Out:
# Average Open Share Price :-  156.33499899999998

# %%
data_set['Open'].value_counts()
# Out:
# 30.000000     6
# 28.000000     6
# 28.500000     5
# 220.000000    5
# 33.500000     4
#              ..
# 84.809998     1
# 86.370003     1
# 88.500000     1
# 91.120003     1
# 257.000000    1
# Name: Open, Length: 1464, dtype: int64

# %%
data_set['Close'].value_counts()
# Out:
# 27.420000     4
# 31.490000     3
# 26.500000     3
# 20.540001     3
# 27.120001     3
#              ..
# 46.970001     1
# 45.450001     1
# 45.590000     1
# 43.299999     1
# 261.500000    1
# Name: Close, Length: 1528, dtype: int64

# %%
print(data_set['High'].value_counts().keys(), "\n", "\n", data_set['Low'].value_counts().keys())
# Out:
# Float64Index([      30.0,       34.5,       28.0,       27.0,  34.799999,
#                29.700001,       28.5,       32.0,  34.400002,  29.889999,
#               ...
#                49.880001,  47.599998,  45.950001,  46.139999,  43.799999,
#                45.139999,  44.549999,  42.009998,  41.830002, 265.329987],
#              dtype='float64', length=1470)
#
#  Float64Index([      28.0,  27.299999,      203.0,       29.5,  28.549999,
#                     26.5,      28.25,       33.5,  20.049999,       27.9,
#               ...
#                88.660004,  78.110001,  81.150002,  79.150002,      69.25,
#                63.689999,  55.709999,  55.119999,       55.5, 261.200012],
#              dtype='float64', length=1468)

# %%
print("Frequency of Share Volum :- \n", data_set['Volume'].value_counts())
# Out:
# Frequency of Share Volum :-
#  986300     2
# 1714500    2
# 922500     2
# 729300     2
# 8998200    2
#           ..
# 884400     1
# 4343400    1
# 1758600    1
# 1527200    1
# 6475900    1
# Name: Volume, Length: 1676, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data_set.dtypes.value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(data_set.isnull(), cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(data_set.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(data=data_set,x="Date",y="High",color="red",label="High")
sns.lineplot(data=data_set,x="Date",y="Low",color="blue",label="Low")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
print(np.sort(data_set['Open']), "This is the Sorted data of Open Share Price")
plt.figure(figsize=(5,5))
plt.bar(list(np.sort(data_set['Open'].value_counts().keys())), list(np.sort(data_set['Open'].value_counts())))
plt.title("Sorted Open Share Price Graph")
plt.xlabel("Price of Share")
plt.ylabel("Frequency")
# Out:
# [ 16.139999  16.4       17.389999 ... 282.98999  284.01001  287.670013] This is the Sorted data of Open Share Price
# Text(0, 0.5, 'Frequency')

# %%
print(np.sort(data_set['Close']), "This is the Sorted data of Close Share Price")
# Out:
# [ 15.8       16.110001  17.049999 ... 282.26001  284.119995 286.040009] This is the Sorted data of Close Share Price

# %%
plt.figure(figsize=(5,5))
plt.bar(list(data_set['Close'].value_counts().keys()), list((data_set['Close'].value_counts())))
plt.title("Sorted Close Share Price Graph")
plt.xlabel("Price of Close Share")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(5,5))
plt.hist(list(data_set['Volume'].value_counts().keys()))
plt.title("Share Volume Graph")
plt.xlabel("Volume of Share")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(6,6))
plt.bar(list(data_set['High'].keys()), list(data_set['Low'].keys()))
plt.xlabel("High")
plt.ylabel("Low")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.bar(data_set['Adj Close'].value_counts().keys(), data_set['Adj Close'].value_counts())
# Out:
# <BarContainer object of 1528 artists>

# %%
plt.figure(figsize=(11, 7))
plt.subplot(131)
plt.plot(list(data_set['High']), list(data_set['Low']), 'o')
plt.title("High")
plt.subplot(132)
plt.scatter(list(data_set['Open']), list(data_set['Close']))
plt.title("Open Daigram")
plt.subplot(133)
plt.plot(list(data_set['Adj Close']))
plt.title("Adj CLose")
plt.suptitle("Categorical Recovered and Deaths daigram")
plt.show()

# %%
np.mean(data_set['Open'])
# Out:
# 132.44157213711588

# %%
data_set.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
bl_col = data_set.select_dtypes(include=('boolean'))
int_col = data_set.select_dtypes(include=('int')).columns
str_col = data_set.select_dtypes(include=('object')).columns

# %%
print(str_col)
# Out:
# Index(['Date'], dtype='object')

# %%
print(data_set.isnull().value_counts(), "There is No null in Dataset")
# Out:
# Date   Open   High   Low    Close  Volume  Adj Close
# False  False  False  False  False  False   False        1692
# dtype: int64 There is No null in Dataset

# %%
for i, col in enumerate(bl_col):
    plt.figure(i)
    sns.countplot(x=col, data=bl_col)

# %%
data_set.hist(figsize=(10, 10))
plt.show()

# %%
data_set.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
sns.jointplot(data=data_set, x='High', y='Open')
sns.jointplot(data=data_set, x='Low', y='Open')
sns.jointplot(data=data_set, x='Close', y='Open')
sns.jointplot(data=data_set, x='Volume', y='Open')

# %%
plt.figure(figsize=(18,16))
sns.heatmap(data_set.corr(), annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
sns.pairplot(data_set)
